# %%
import requests,re
input_html = """<ol class="rounded-list">

 <!--   -->

   <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/116/35/1">ANDAMAN &amp; NICOBAR ISLANDS&nbsp;(116)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/3994/28/1">ANDHRA PRADESH&nbsp;(3994)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/399/12/1">ARUNACHAL PRADESH&nbsp;(399)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/1824/18/1">ASSAM&nbsp;(1824)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/3569/10/1">BIHAR&nbsp;(3569)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/179/4/1">CHANDIGARH&nbsp;(179)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/1547/22/1">CHHATTISGARH&nbsp;(1547)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/24/26/1">DADRA &amp; NAGAR HAVELI&nbsp;(24)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/15/25/1">DAMAN &amp; DIU&nbsp;(15)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/8018/7/1">DELHI&nbsp;(8018)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/213/30/1">GOA&nbsp;(213)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/5127/24/1">GUJARAT&nbsp;(5127)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/2266/6/1">HARYANA&nbsp;(2266)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/631/2/1">HIMACHAL PRADESH&nbsp;(631)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/1260/1/1">JAMMU &amp; KASHMIR&nbsp;(1260)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/1824/20/1">JHARKHAND&nbsp;(1824)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/5930/29/1">KARNATAKA&nbsp;(5930)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/3114/32/1">KERALA&nbsp;(3114)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/145/37/1">LADAKH&nbsp;(145)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/2/31/1">LAKSHADWEEP&nbsp;(2)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/5357/23/1">MADHYA PRADESH&nbsp;(5357)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/14281/27/1">MAHARASHTRA&nbsp;(14281)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/2092/14/1">MANIPUR&nbsp;(2092)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/241/17/1">MEGHALAYA&nbsp;(241)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/199/15/1">MIZORAM&nbsp;(199)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/360/13/1">NAGALAND&nbsp;(360)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/3190/21/1">ORISSA&nbsp;(3190)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/257/34/1">PUDUCHERRY&nbsp;(257)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/1329/3/1">PUNJAB&nbsp;(1329)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/3983/8/1">RAJASTHAN&nbsp;(3983)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/93/11/1">SIKKIM&nbsp;(93)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/7404/33/1">TAMIL NADU&nbsp;(7404)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/2361/36/1">TELANGANA&nbsp;(2361)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/401/16/1">TRIPURA&nbsp;(401)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/14747/9/1">UTTAR PRADESH&nbsp;(14747)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/1537/5/1">UTTARAKHAND&nbsp;(1537)</a></li>
    <li><a class="bluelink11px" href="https://ngodarpan.gov.in/index.php/home/statewise_ngo/8046/19/1">WEST BENGAL&nbsp;(8046)</a></li>
  
</ol>"""
import requests
import json
def get_data(ngoid,token):
    cookie = f'ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name={token}'
    print (cookie)
    headers = {
        'Connection': 'keep-alive',
        'sec-ch-ua': '"Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87"',
        'Accept': '*/*',
        'DNT': '1',
        'X-Requested-With': 'XMLHttpRequest',
        'sec-ch-ua-mobile': '?0',
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36',
        'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'Origin': 'https://ngodarpan.gov.in',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Dest': 'empty',
        'Referer': 'https://ngodarpan.gov.in/index.php/home/statewise_ngo/116/35/1',
        'Accept-Language': 'en-US,en;q=0.9,hi-IN;q=0.8,hi;q=0.7,da;q=0.6',
        'Cookie': f'ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name={token}',
        
    }
    data = {
      'id': ngoid,
      'csrf_test_name': token,
    }
    response = requests.post('https://ngodarpan.gov.in/index.php/ajaxcontroller/show_ngo_info', headers=headers,data=data)
    return response
def get_cookie():
    headers = {
        'Connection': 'keep-alive',
        'sec-ch-ua': '"Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87"',
        'Accept': 'application/json, text/javascript, */*; q=0.01',
        'DNT': '1',
        'X-Requested-With': 'XMLHttpRequest',
        'sec-ch-ua-mobile': '?0',
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Dest': 'empty',
        'Referer': 'https://ngodarpan.gov.in/index.php/home/statewise_ngo/8046/19/1',
        'Accept-Language': 'en-US,en;q=0.9,hi-IN;q=0.8,hi;q=0.7,da;q=0.6',
        
    }

    response = requests.get('https://ngodarpan.gov.in/index.php/ajaxcontroller/get_csrf', headers=headers)
    return response

def store_data(ngoid):
    c = get_cookie()
    active_token = c.json().get('csrf_token')
    data=get_data(ngoid,active_token).json()
    open("data.jsonl","a").write(json.dumps(data)+"\n")
from bs4 import BeautifulSoup as bs
statelinks = [i.attrs['href'] for i in bs(input_html).select("a.bluelink11px")]
statelist=statelinks[:10]
def gotopage(homepage,pagenum):
    root = "https://ngodarpan.gov.in/index.php/home/statewise_ngo/"
    numsections = homepage.replace(root,"").split("/")
    numsections[-1] = str(pagenum)
    newHomePage = root+"/".join(numsections)
    return newHomePage

def process_state(state):
    last_page = None
    statehtml = requests.get(state)
    for link in bs(statehtml.content).select("a"):
        if link.text == "Last":
            last_page=link.attrs["data-ci-pagination-page"]
    for i in range(1,int(last_page)+1):
        pagetovisit = gotopage("https://ngodarpan.gov.in/index.php/home/statewise_ngo/8046/19/1",i)
        pagehtml = requests.get(pagetovisit,timeout=10).content
        bspagehtml = bs(pagehtml)
        tbl = bspagehtml.select(".ibox-content tbody tr")
        for tr in tbl:
            tds = tr.select("a")[0].attrs["onclick"]
            number = re.sub(r"\D", "", tds)
            print (int(number))
            try:
                store_data(int(number))
            except:
                pass
# for state in statelist:
#     process_state(state)
#     open("done_state","a").write(state+"\n")

# %%
process_state(statelist[0])
# Out:
# 155561
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=4e62fc6525eb9ea800ab0173a5a74fd8
# 175398
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=ba050fe87aba0b36db8f7c5e9ec245d2
# 175604
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=309e05016e35361639965773b031355a
# 202865
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=eb9d838aa0267f53dd089772c0ca9b16
# 257042
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=5f0d295d0f61e73d32ccf045ab401cc0
# 200790
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=44280a2ae72477cc5dee5ac25ecb6477
# 200709
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=ddef5ca36f805c21465a0adac7c0e31b
# 252181
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=30518cfffaec21b83176e0b6285e1356
# 152375
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=7ef510c855c49e464e8b02e0f4b155b1
# 173802
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=4026bdb8899ab4974d4f6db044b0e054
# 184167
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=01324d9458dbb12ecd30b33dee121444
# 226673
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=f43e1a66fa9523190eff0994ab79a3f1
# 185763
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=1f21a8a8cbf0b9423e61cf97c50770af
# 208655
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=faafc1133a1535709621980253234e33
# 201087
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=e71bede474578046ce1a66477f7623d4
# 243254
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=dc3c49009da149dedb2da89512d9e7de
# 207638
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=d1caf2019d6a121030d96fa9eb8c432d
# 229121
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=b813a7ce1a458edfa0bc438c58b9d75c
# 150751
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=9c7d5654351837a04be8f537120e2153
# 193279
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=1a1831c2ef6bcb58ab7aa646507f8fe2
# 209789
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=1267a2e406b925946c01ac6319d26f7d
# 264634
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=9dcf07ca0f8387fa25cdb1811b17ecf0
# 244959
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=42f39426223168c66e06061feed34bc7
# 177601
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=cf8677f9c4660bfc913048ee556d82cc
# 220453
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=d226f1ddd3ec3ea2ba144f840564abd8
# 103822
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=6ae9ab518057581d44e14aee9dc46c9a
# 252328
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=192976aafb4e44a754d881f3b31d2957
# 239716
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=ccdecadc0942349d1deacc3654b2754f
# 210802
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=b8c4fa5268cee92d813bd8fe690131ea
# 108824
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=c06100a1fc77e3a20d0a77a892213454
# 237402
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=2c26302e885d5dfd48b32fbbd6815d59
# 241379
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=7c88c89c4ea12c280051a6a78a0bc42a
# 273308
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=e6e7cbb220c9adaec543df6c410176d3
# 103825
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=dc957a3f2f49467ed49ea1d0a2009370
# 7201
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=2ef13b7d82efa24d371c612a0f089501
# 260244
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=50f4ef3c8f4785e8d35e575b7021a0c0
# 205222
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=7e381149f2cb29e3ca8a8a2f24fac722
# 229190
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=60e2b9eae31865ec71eb14670e64e4ae
# 199674
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=4eb27135fb02449fc7896e43595904fc
# 72457
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=34cbe6f8b7b5b7f6017a9a184716d6d8
# 181398
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=964994a75df54ee34748bb1d6f2c4372
# 270331
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=6371a21db578006ab0dfc1d3c3dfb9a7
# 206951
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=a8d9ab516388e8843f4928d7f5509a32
# 235207
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=e3498a5f8f29fbc9001bfa7628ae919a
# 254665
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=538748eff7ff245a7d7d47790b8263fb
# 254356
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=b265c66ec945ef6e9508da92b78fa0d4
# 119133
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=77ebcde721675f232905e197273d034f
# 178242
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=4b3095d7392e5339d2efd1e22cd11111
# 216685
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=86286677f3fbc40dd9014ebd5015db2d
# 272119
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=8f0ed3fd7443c5aa24f296c68c4d4c04
# 270533
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=c17ed78cc3a4aedccbc97ea71cd6b755
# 262088
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=b7571247092204b960003c623de10b63
# 172140
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=30df62c7eacbfe364ce287419635f4ec
# 229784
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=9f93a7ff0b2d13b62960ffd44912ed11
# 116917
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=75c6b85fdf74fd5b606c30a084d08525
# 271006
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=691b666778011b30b54ca4267ac9af8d
# 198296
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=a5e0165ede9935a83bb320e84a2549a6
# 246590
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=9b28e711ea18a7d8dfd7a7fd0f858d06
# 193788
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=d2ba5bedf71aa4f6e1fddaf2ab8f9022
# 250965
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=322c2974a29e4dc14669b6f08262f58d
# 160968
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=5da9a8f0c592c4401a22e9f16f29abf5
# 192961
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=556cbd2765e91416c03cbabfa8ff1214
# 20452
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=2a7485434fdf77bb88b40942a4747fcf
# 251110
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=ea541717663d41e18fb965cdde3117a1
# 234442
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=2fb2d60f9459fa3555d5942e59a90813
# 240152
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=fbe1d2e00acf40ff1dba86c227968a6b
# 218480
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=d6e4b187b87d249ea716c6a15e1be7e6
# 201069
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=f0311856dedd0837a4e91173e40b1f0c
# 183681
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=3d501433bf17ce730b84547428b298a5
# 201812
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=f324fdd4bb7c7902320b876fc4769d3e
# 38945
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=96682f9434ae71d8578023ccb4d1fc64
# 242262
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=159c3768df344ad8be4e826b1fb237d0
# 245569
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=761cba26aa4ae40ad16f27ef1a4a74d2
# 249276
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=3529d77e4e069ba560cca42e7e03f742
# 20523
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=99c5d75f7c51fe0968d7eb51c1ecef0a
# 250256
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=7b378f96563e7435712f65f77eaea1d1
# 178496
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=33b1944c14cc27eaf40ba713f1e6fa2f
# 252675
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=0c8f3a6af0460bbc6b1281db4da4a26b
# 163497
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=450b5246c6b571d3f31b6562552bebae
# 200290
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=6fd54da43fe2679a24945d4c51af4ccf
# 248409
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=4610ebaab953f01891a8e7c109a05650
# 113555
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=512fc6fdcb03b37851c27cf555d3cacc
# 175912
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=149fdf3bb5757cb6f1c7358d9282bb62
# 70199
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=37bba3e98657821b01bc9a44dc67df3a
# 257810
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=afcd76c8999e4fa17468c2dfb893318d
# 221857
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=b337ad69835066a7e1a7cc5f2c09c90b
# 111578
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=d3db76f447e484942f7ac168decf265b
# 237096
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=cfbb1110efd6dc4fc4b003a02eb80059
# 259116
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=8a401bcfb93102e1be24dbc00618262a
# 243579
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=ed460526ec7113c3e43017733c93cc5d
# 185733
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=f997c581c23a6677038849c7bf880f22
# 91836
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=e1268bf8eb0b78e69fafa12aec7c811f
# 153627
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=9aa64c85b1b147943f295b6daf115b6c
# 218019
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=3d069c5ebd5c78a4d2c81ee1f6333794
# 70729
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=c74e96062ed7c148d6519a24921c5d79
# 244494
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=be4776330ba34b43d1097b2f7cd13baf
# 257097
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=84fdb9eac1f31a9fd5c7df97f09e2282
# 165143
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=9ec106fc81bbf962a1269a296d3c46cd
# 255279
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=485b47f3581dbc14ad00fe8a77392118
# 209562
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=8fa36cba3c051b7c2fb43f90e6521385
# 266631
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=77c67fb4f1e3ac69cca6be8c41c3e464
# 265932
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=ce45d62f0875b2acd95e2827cdaeba6e
# 175129
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=42150d46e9e1fb5f8f7115ad84291d6c
# 153055
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=710e53efc73cb0f39b18314eb06c0269
# 260372
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=c1c8f30c18b63e31260dcbd296351d7d
# 157902
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=f2c3a9110af06179413a2df06ad45a52
# 187548
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=ca32978702d781dfe73f81bc579e1b45
# 253744
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=80ca63efd5d334467fd9f67b5414e66a
# 173769
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=bc33a023b76e68891aa8eca548af5362
# 272769
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=e2f5d3675ebe4aaaeaa276bcc9b1c880
# 157767
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=b9ea155aeb1baff17389c0625bd26700
# 216106
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=2c1e393e77a04f85e2cec7ca5b20a93e
# 269381
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=451496308fe8a98c6c128c5a4c72ced4
# 223691
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=3e8a4a2bb6cb24cc863720c8cbeaae74
# 253006
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=02bf30b17a7261040080b59747cb40cc
# 222363
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=3662bc9495af7d0410a0d92208d74dc5
# 176656
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=497c102e8040f23cd7ce015fada378c6
# 154849
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=c538e4b9e6526dd9a6f5d18a24b11434
# 37118
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=81130415d340fd3ec3e4a947abe8b984
# 17611
# ci_session=qra1cna4ijclvtem2hlr7k7v7ej98fe6; csrf_cookie_name=0b871363f1da84a570ae711357394142
